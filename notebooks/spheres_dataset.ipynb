# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn import decomposition

from topo_ae.data import spheres

# %%
tf.norm
# Out:
# <function tensorflow.python.ops.linalg_ops.norm_v2(tensor, ord='euclidean', axis=None, keepdims=None, name=None)>

# %%
n_points = 500
samples, labels = spheres(n_points, dimension=100, noise=None)
plt.scatter(*decomposition.PCA(n_components=2).fit_transform(samples)[::-1].T, c=labels[::-1], alpha=0.5)

# %%
len(samples)
# Out:
# 10000
